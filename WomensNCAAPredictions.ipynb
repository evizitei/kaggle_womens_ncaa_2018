# %% [markdown]
# # Data Exploration

# %%
import pandas as pd
import numpy as np

# %%
team_names = pd.read_csv("./data/WDataFiles/WTeams.csv")
seasons = pd.read_csv("./data/WDataFiles/WSeasons.csv")
seeds = pd.read_csv("./data/WDataFiles/WNCAATourneySeeds.csv")
season_results = pd.read_csv("./data/WDataFiles/WRegularSeasonCompactResults.csv")
tourney_results = pd.read_csv("./data/WDataFiles/WNCAATourneyCompactResults.csv")
cities = pd.read_csv("./data/WDataFiles/WCities.csv")
game_cities = pd.read_csv("./data/WDataFiles/WGameCities.csv")

# %%
seasons.head()
# Out:
#    Season     DayZero RegionW  RegionX  RegionY  RegionZ
# 0    1998  10/27/1997    East  Midwest  Mideast     West
# 1    1999  10/26/1998    East  Mideast  Midwest     West
# 2    2000   11/1/1999    East  Midwest  Mideast     West
# 3    2001  10/30/2000    East  Midwest  Mideast     West
# 4    2002  10/29/2001    East     West  Mideast  Midwest

# %%
seeds.head()
# Out:
#    Season Seed  TeamID
# 0    1998  W01    3330
# 1    1998  W02    3163
# 2    1998  W03    3112
# 3    1998  W04    3301
# 4    1998  W05    3272

# %%
tourney_results.tail()
# Out:
#       Season  DayNum  WTeamID  WScore  LTeamID  LScore WLoc  NumOT
# 1255    2017     147     3163      90     3332      52    H      0
# 1256    2017     147     3376      71     3199      64    N      0
# 1257    2017     151     3280      66     3163      64    N      1
# 1258    2017     151     3376      62     3390      53    N      0
# 1259    2017     153     3376      67     3280      55    N      0

# %% [markdown]
# ### Intuitions to follow up on
#
# * Does being on home court increase probability of a win?
# * Does the outcome of the prior game for this team give them "momentum"?
# * Do Win/Loss ratios for the season so far correlate with wins?
# * Does seed distance from opponent correlate with winning?
# * Does prior season normalized points scored with respect to total distribution correlate with winning?
# * same question for season-to-date
# * same question for historical and season-to-date defense
# * can we easily determine distances from all cities to all other cities?  Do we know the home city for each team?  If so can we use distance from home city to game city as a proxy for travel fatigue? And does it affect winning outcomes?
# * are relative win-ratios from regular season play predictive of tournament wins?
# * are there different regional strengths?

# %% [markdown]
# ## Stage 1 Predictions
#
# The first portion of this exercise involves successfully predicting matchups from past tournaments.  The goal is to take the 64 teams in each tournament, and predict each possible matchup.  To get the formatting right, I'll build a model that extracts the seed for each tournament, and tries to learn a naive predictor just based on seed difference between teams.  Steps:
#
# * 1: Make training set from tournament results.
#   - extract seed 1 and seed 2
#   - make Y vector, 1 for a team 1 victory, 0 for team 2 victory
#   - teams in a match ordered by numeric ID
#
# * 2: train model to convergence on entire batch
#
# * 3: Make a test set from seeds list for all possible combinations and seed numbers
#
# * 4: predict results and confirm an output size of 8,064 data rows.

# %%
from sklearn.linear_model import LogisticRegression
import itertools
import csv
    
def figure_team_1(row):
    if row['Team1Win']:
        return row['WTeamID']
    else:
        return row['LTeamID']

def figure_team_2(row):
    if row['Team1Win']:
        return row['LTeamID']
    else:
        return row['WTeamID']

def training_set_baseline(tourney_results_df, seeds_df):
    tourney_df = tourney_results_df[['Season','WTeamID','LTeamID']]
    tourney_df['Team1Win'] = tourney_df['WTeamID'] < tourney_df['LTeamID']
    tourney_df['Team1'] = tourney_df.apply(figure_team_1,axis=1)
    tourney_df['Team2'] = tourney_df.apply(figure_team_2,axis=1)
    training_df = pd.merge(tourney_df, seeds_df, left_on=['Season', 'Team1'], right_on=['Season', 'TeamID'])
    training_df = training_df.rename(index=str, columns={"Seed": "Team1Seed"})
    training_df = training_df.drop(['TeamID'], axis=1)
    training_df = pd.merge(training_df, seeds_df, left_on=['Season', 'Team2'], right_on=['Season', 'TeamID'])
    training_df = training_df.rename(index=str, columns={"Seed": "Team2Seed"})
    training_df = training_df.drop(['TeamID'], axis=1)
    training_df['SeedNum1'] = training_df.apply(lambda row: int(row['Team1Seed'][1:3]), axis=1)
    training_df['SeedNum2'] = training_df.apply(lambda row: int(row['Team2Seed'][1:3]), axis=1)
    training_df['SeedDelta'] = (training_df['SeedNum1'] - training_df['SeedNum2'])
    seed_mu = training_df['SeedDelta'].mean()
    seed_sigma = training_df['SeedDelta'].std()
    training_df['NormalizedSeedDelta'] = (training_df['SeedDelta'] - seed_mu) / seed_sigma
    return training_df, { 'seed_mu': seed_mu, 'seed_sigma': seed_sigma }

def test_set_frame(seeds_df, training_meta):
    test_seeds = seeds_df[['Season', 'Seed', 'TeamID']]
    test_seeds['SeedNum'] = test_seeds.apply(lambda row: int(row['Seed'][1:3]), axis=1)
    seasons = np.unique(test_seeds.Season.values)
    test_set = [] # output_key (SSSS_XXXX_YYYY), seed1, seed2, seed_delta
    seasons = [ss for ss in seasons if ss >= 2014 and ss < 2018]
    for s in seasons:
        seed_set = test_seeds[test_seeds.Season == s].values
        for seed_pair in itertools.combinations(seed_set, 2):
            id_a = seed_pair[0][2]
            id_b = seed_pair[1][2]
            t1 = 0
            t2 = 0
            s1 = 0
            s2 = 0
            if id_a < id_b:
                t1 = id_a
                t2 = id_b
                s1 = seed_pair[0][3]
                s2 = seed_pair[1][3]
            else:
                t1 = id_b
                t2 = id_a
                s1 = seed_pair[1][3]
                s2 = seed_pair[0][3]
            output_key = "%s_%s_%s" % (s, t1, t2)
            test_set.append([output_key, s, t1, t2, s1, s2])
    tdf = pd.DataFrame(data=test_set, columns=['Key', 'Season', 'Team1', 'Team2', 'SeedNum1', 'SeedNum2'])
    tdf['SeedDelta'] = (tdf['SeedNum1'] - tdf['SeedNum2'])
    tdf['NormalizedSeedDelta'] = (tdf['SeedDelta'] - training_meta['seed_mu']) / training_meta['seed_sigma']
    return tdf
    
def test_set_baseline(seeds_df, training_meta):
    test_df = test_set_frame(seeds_df, training_meta)
    test_set = test_df[['Key', 'SeedNum1', 'SeedNum2', 'NormalizedSeedDelta']].values
    return test_set

def predict_with_naive_model(test_ds, model):
    test_x = test_ds[:, 3].astype(float)
    test_x = test_x.reshape(len(test_x), 1)
    predictions = model.predict_proba(test_x)[:, 1]
    return predictions
    
def build_naive_model(training_df):
    x_train = training_df['NormalizedSeedDelta'].values
    y_train = np.vectorize(lambda x: 1 if x else 0)(training_df['Team1Win'].values)
    x_train = x_train.reshape(len(x_train), 1)
    y_train = y_train.reshape(len(y_train), )
    naive_model = LogisticRegression()
    naive_model = naive_model.fit(x_train, y_train)
    print("SCORE: ", naive_model.score(x_train, y_train))
    return naive_model

def write_predictions(test_set, preds):
    with open("./data/outputs/stage_1_predictions.csv", "w") as f:
        wtr = csv.writer(f)
        wtr.writerow(['ID','Pred'])
        for i in range(len(test_set)):
            out_key = test_set[i][0]
            prediction = preds[i]
            wtr.writerow([out_key,prediction])

# %%
training_df, training_meta = training_set_baseline(tourney_results, seeds)
# Out:
# /Users/ethan/anaconda/envs/kaggle/lib/python3.6/site-packages/ipykernel_launcher.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/ethan/anaconda/envs/kaggle/lib/python3.6/site-packages/ipykernel_launcher.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/ethan/anaconda/envs/kaggle/lib/python3.6/site-packages/ipykernel_launcher.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
training_df.head(10)
# Out:
#    Season  WTeamID  LTeamID  Team1Win  Team1  Team2 Team1Seed Team2Seed  \
# 0    1998     3104     3422      True   3104   3422       X02       X15
# 1    1998     3104     3417      True   3104   3417       X02       X07
# 2    1998     3417     3276     False   3276   3417       X10       X07
# 3    1998     3256     3104     False   3104   3256       X02       X03
# 4    1998     3256     3155     False   3155   3256       X06       X03
# 5    1998     3256     3221     False   3221   3256       X14       X03
# 6    1998     3112     3365      True   3112   3365       W03       W14
# 7    1998     3112     3438      True   3112   3438       W03       W06
# 8    1998     3438     3374     False   3374   3438       W11       W06
# 9    1998     3163     3112     False   3112   3163       W03       W02
#
#    SeedNum1  SeedNum2  SeedDelta  NormalizedSeedDelta
# 0         2        15        -13            -1.751175
# 1         2         7         -5            -0.672212
# 2        10         7          3             0.406752
# 3         2         3         -1            -0.132730
# 4         6         3          3             0.406752
# 5        14         3         11             1.485716
# 6         3        14        -11            -1.481434
# 7         3         6         -3            -0.402471
# 8        11         6          5             0.676493
# 9         3         2          1             0.137011

# %%
current_model = build_naive_model(training_df)
current_test_set = test_set_baseline(seeds, training_meta)
predictions = predict_with_naive_model(current_test_set, current_model)
# Out:
# SCORE:  0.778571428571

# %% [markdown]
# ## write first naive predictions file to get the format down right

# %%
write_predictions(current_test_set, predictions)

# %% [markdown]
# ## RESULTS For Naive Model:
# * ACCURACY ON TRAINING: 0.7786
# * TESTING SCORE: 0.4626

# %% [markdown]
# ## including other features
#
# Some other features that are likely to be helpful are offensive and defensive information for each team, so lets' try median offensive and defensive points for the regular season as a feature.

# %%
def build_all_scores(season_df):
    w_scores = season_df[['Season', 'WTeamID', 'WScore']].rename(index=str, columns={"WTeamID": "TeamID", "WScore": "Score"})
    l_scores = season_df[['Season', 'LTeamID', 'LScore']].rename(index=str, columns={"LTeamID": "TeamID", "LScore": "Score"})
    all_scores = pd.concat([w_scores, l_scores])
    grouped_scores = all_scores.groupby(['Season', 'TeamID'], as_index=False).aggregate(np.median)
    return grouped_scores
    
def training_set_with_scores(tourney_results_df, seeds_df, season_df):
    baseline_df, training_meta = training_set_baseline(tourney_results_df, seeds_df)
    grouped_scores = build_all_scores(season_df)
    score_mu = grouped_scores['Score'].mean()
    score_sigma = grouped_scores['Score'].std()
    training_meta['score_mu'] = score_mu
    training_meta['score_sigma'] = score_sigma

    training_df = pd.merge(baseline_df, grouped_scores, left_on=['Season', 'Team1'], right_on=['Season', 'TeamID'])
    training_df = training_df.rename(index=str, columns={"Score": "Team1MedianScore"})
    training_df = training_df.drop(['TeamID'], axis=1)
    training_df = pd.merge(training_df, grouped_scores, left_on=['Season', 'Team2'], right_on=['Season', 'TeamID'])
    training_df = training_df.rename(index=str, columns={"Score": "Team2MedianScore"})
    training_df = training_df.drop(['TeamID'], axis=1)
    training_df['Team1NormedScore'] = (training_df['Team1MedianScore'] - score_mu) / (score_sigma ** 2)
    training_df['Team2NormedScore'] = (training_df['Team2MedianScore'] - score_mu) / (score_sigma ** 2)
    return training_df, training_meta

def build_multifeature_naive_model(training_df):
    x_train = training_df[['NormalizedSeedDelta', 'Team1NormedScore', 'Team2NormedScore']].values
    y_train = np.vectorize(lambda x: 1 if x else 0)(training_df['Team1Win'].values)
    x_train = x_train.reshape(len(x_train), 3)
    y_train = y_train.reshape(len(y_train), )
    naive_model = LogisticRegression()
    naive_model = naive_model.fit(x_train, y_train)
    print("SCORE: ", naive_model.score(x_train, y_train))
    return naive_model

def predict_with_multi_naive_model(test_df, model):
    test_x = test_df[['NormalizedSeedDelta', 'Team1NormedScore', 'Team2NormedScore']].values
    test_x.reshape(len(test_x), 3)
    predictions = model.predict_proba(test_x)[:, 1]
    return predictions

def test_set_with_scores(seeds_df, season_df, training_meta):
    tdf = test_set_frame(seeds_df, training_meta)
    grouped_scores = build_all_scores(season_df)
    
    score_mu = training_meta['score_mu']
    score_sigma = training_meta['score_sigma']

    test_df = pd.merge(tdf, grouped_scores, left_on=['Season', 'Team1'], right_on=['Season', 'TeamID'])
    test_df = test_df.rename(index=str, columns={"Score": "Team1MedianScore"})
    test_df = test_df.drop(['TeamID'], axis=1)
    test_df = pd.merge(test_df, grouped_scores, left_on=['Season', 'Team2'], right_on=['Season', 'TeamID'])
    test_df = test_df.rename(index=str, columns={"Score": "Team2MedianScore"})
    test_df = test_df.drop(['TeamID'], axis=1)
    test_df['Team1NormedScore'] = (test_df['Team1MedianScore'] - score_mu) / (score_sigma ** 2)
    test_df['Team2NormedScore'] = (test_df['Team2MedianScore'] - score_mu) / (score_sigma ** 2)
    
    return test_df

# %%
training_set, meta = training_set_with_scores(tourney_results, seeds,season_results)
# Out:
# /Users/ethan/anaconda/envs/kaggle/lib/python3.6/site-packages/ipykernel_launcher.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/ethan/anaconda/envs/kaggle/lib/python3.6/site-packages/ipykernel_launcher.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/ethan/anaconda/envs/kaggle/lib/python3.6/site-packages/ipykernel_launcher.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
training_set.head()
# Out:
#    Season  WTeamID  LTeamID  Team1Win  Team1  Team2 Team1Seed Team2Seed  \
# 0    1998     3104     3422      True   3104   3422       X02       X15
# 1    1998     3104     3417      True   3104   3417       X02       X07
# 2    1998     3417     3276     False   3276   3417       X10       X07
# 3    1998     3256     3104     False   3104   3256       X02       X03
# 4    1998     3256     3155     False   3155   3256       X06       X03
#
#    SeedNum1  SeedNum2  SeedDelta  NormalizedSeedDelta  Team1MedianScore  \
# 0         2        15        -13            -1.751175              74.0
# 1         2         7         -5            -0.672212              74.0
# 2        10         7          3             0.406752              77.0
# 3         2         3         -1            -0.132730              74.0
# 4         6         3          3             0.406752              73.0
#
#    Team2MedianScore  Team1NormedScore  Team2NormedScore
# 0              75.0          0.197045          0.217213
# 1              80.0          0.197045          0.318050
# 2              80.0          0.257547          0.318050
# 3              86.0          0.197045          0.439054
# 4              86.0          0.176878          0.439054

# %%
multifeature_model = build_multifeature_naive_model(training_set)
# Out:
# SCORE:  0.786507936508

# %%
current_test_set = test_set_with_scores(seeds, season_results, meta)
predictions = predict_with_multi_naive_model(current_test_set, multifeature_model)

# %%
write_predictions(current_test_set['Key'].values.reshape((len(current_test_set), 1)), predictions)

# %% [markdown]
# ## RESULTS For Model 2 (seeds and scoring history):
# * ACCURACY ON TRAINING: 0.7865
# * TESTING SCORE: 0.4582

# %%
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout

def build_deep_model(input_features):
    model = Sequential()
    model.add(Dense(128, input_dim=input_features))
    model.add(Activation('relu'))
    model.add(Dropout(0.5))
    model.add(Dense(128))
    model.add(Activation('relu'))
    model.add(Dropout(0.5))
    model.add(Dense(1))
    model.add(Activation('sigmoid'))
    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
    return model

def train_deep_model(training_df):
    x_train = training_df[['NormalizedSeedDelta', 'Team1NormedScore', 'Team2NormedScore']].values
    y_train = np.vectorize(lambda x: 1 if x else 0)(training_df['Team1Win'].values)
    x_train = x_train.reshape(len(x_train), 3)
    y_train = y_train.reshape(len(y_train), )
    model = build_deep_model(3)
    model.fit(x_train, y_train, epochs=10000, batch_size=len(x_train), verbose=2)
    return model

def score_deep_model(training_df, model):
    x_train = training_df[['NormalizedSeedDelta', 'Team1NormedScore', 'Team2NormedScore']].values
    y_train = np.vectorize(lambda x: 1 if x else 0)(training_df['Team1Win'].values)
    x_train = x_train.reshape(len(x_train), 3)
    y_train = y_train.reshape(len(y_train), )
    return model.evaluate(x_train, y_train)

def predict_with_deep_model(test_df, model):
    test_x = test_df[['NormalizedSeedDelta', 'Team1NormedScore', 'Team2NormedScore']].values
    test_x.reshape(len(test_x), 3)
    predictions = model.predict(test_x)[:, 0]
    return predictions

# %%
d_model = train_deep_model(training_set)

# %%
d_predictios = predict_with_deep_model(current_test_set, d_model)

# %%
write_predictions(current_test_set['Key'].values.reshape((len(current_test_set), 1)), d_predictios)

# %%
score_deep_model(training_set, d_model)
# Out:
# 1260/1260 [==============================] - 0s 30us/step
# [0.34670683334744168, 0.83174603193525287]

# %% [markdown]
# ## First Deep Model Results
#
# - ACCURACY ON TRAINING: 0.8317
# - KAGGLE TESTING SCORE: 0.3683
#
# ***THESE

# %% [markdown]
# #### Improvement Ideas:
# - Include mean spread
# - Include exponentially-weighted average of point spread over the season
# - Include spread variance
# - Include Normalized Seed Num
# - Batch Norm Model

# %%
def calculate_spreads(season_df):
    score_df = season_df[['Season', 'DayNum', 'WTeamID', 'WScore', 'LTeamID', 'LScore']]
    score_df['WSpread'] = score_df['WScore'] - score_df['LScore']
    score_df['LSpread'] = score_df['WSpread'] * -1
    w_spreads = score_df[['Season','DayNum','WTeamID', 'WSpread']].rename(index=str, columns={'WTeamID': 'TeamID', 'WSpread': 'Spread'})
    l_spreads = score_df[['Season','DayNum','LTeamID', 'LSpread']].rename(index=str, columns={'LTeamID': 'TeamID', 'LSpread': 'Spread'})
    spreads_df = pd.concat([w_spreads, l_spreads]).sort_values(['Season','DayNum'])
    seasons = spreads_df['Season'].unique()
    teams = spreads_df['TeamID'].unique()
    join_frame = []
    for season in seasons:
        for team in teams:
            spreads = spreads_df[(spreads_df.Season == season) & (spreads_df.TeamID == team)].Spread
            mean_spread = spreads.mean()
            std_spread = spreads.std()
            ew_beta = 0.8
            expo_spread = 0
            for spread in spreads.values:
                expo_spread = (ew_beta * expo_spread) + (1 - ew_beta) * spread
            join_frame.append([season, team, mean_spread, std_spread, expo_spread])
    return pd.DataFrame(data=join_frame, columns=['Season', 'TeamID', 'MeanSpread', 'StdSpread', 'ExpoSpread'])
    

def training_set_with_spreads(tourney_df, seeds_df, season_df, spreads_df):
    train_df, meta = training_set_with_scores(tourney_df, seeds_df, season_df)
    train_df['Team1NormedSeed'] = (train_df['SeedNum1'] - 8) / 8
    train_df['Team2NormedSeed'] = (train_df['SeedNum2'] - 8) / 8
    
    meta['spread_mean_mu'] = spreads_df['MeanSpread'].mean()
    meta['spread_std_mu'] = spreads_df['StdSpread'].mean()
    meta['spread_expo_mu'] = spreads_df['ExpoSpread'].mean()
    meta['spread_mean_sigma'] = spreads_df['MeanSpread'].std() ** 2
    meta['spread_std_sigma'] = spreads_df['StdSpread'].std() ** 2
    meta['spread_expo_sigma'] = spreads_df['ExpoSpread'].std() ** 2

    training_df = pd.merge(train_df, spreads_df, left_on=['Season', 'Team1'], right_on=['Season', 'TeamID'])
    training_df = training_df.rename(index=str, columns={"MeanSpread": "Team1MeanSpread", "StdSpread": "Team1StdSpread", "ExpoSpread": "Team1ExpoSpread"})
    training_df = training_df.drop(['TeamID'], axis=1)
    training_df = pd.merge(training_df, spreads_df, left_on=['Season', 'Team2'], right_on=['Season', 'TeamID'])
    training_df = training_df.rename(index=str, columns={"MeanSpread": "Team2MeanSpread", "StdSpread": "Team2StdSpread", "ExpoSpread": "Team2ExpoSpread"})
    training_df = training_df.drop(['TeamID'], axis=1)
    
    training_df['Team1NormMeanSpread'] = (training_df['Team1MeanSpread'] - meta['spread_mean_mu']) / meta['spread_mean_sigma']
    training_df['Team2NormMeanSpread'] = (training_df['Team2MeanSpread'] - meta['spread_mean_mu']) / meta['spread_mean_sigma']
    training_df['Team1NormStdSpread'] = (training_df['Team1StdSpread'] - meta['spread_std_mu']) / meta['spread_std_sigma']
    training_df['Team2NormStdSpread'] = (training_df['Team2StdSpread'] - meta['spread_std_mu']) / meta['spread_std_sigma']
    training_df['Team1NormExpSpread'] = (training_df['Team1ExpoSpread'] - meta['spread_expo_mu']) / meta['spread_expo_sigma']
    training_df['Team2NormExpSpread'] = (training_df['Team2ExpoSpread'] - meta['spread_expo_mu']) / meta['spread_expo_sigma']
    
    return training_df.sample(frac=1), meta

def test_set_with_spreads(seeds_df, season_df, training_meta, spreads_df):
    test_df = test_set_with_scores(seeds_df, season_df, training_meta)
    grouped_scores = build_all_scores(season_df)
    
    spread_mean_mu = training_meta['spread_mean_mu']
    spread_std_mu = training_meta['spread_std_mu']
    spread_expo_mu = training_meta['spread_expo_mu']
    spread_mean_sigma = training_meta['spread_mean_sigma']
    spread_std_sigma = training_meta['spread_std_sigma']
    spread_expo_sigma = training_meta['spread_expo_sigma']
    
    test_df['Team1NormedSeed'] = (test_df['SeedNum1'] - 8) / 8
    test_df['Team2NormedSeed'] = (test_df['SeedNum2'] - 8) / 8
    
    test_df = pd.merge(test_df, spreads_df, left_on=['Season', 'Team1'], right_on=['Season', 'TeamID'])
    test_df = test_df.rename(index=str, columns={"MeanSpread": "Team1MeanSpread", "StdSpread": "Team1StdSpread", "ExpoSpread": "Team1ExpoSpread"})
    test_df = test_df.drop(['TeamID'], axis=1)
    test_df = pd.merge(test_df, spreads_df, left_on=['Season', 'Team2'], right_on=['Season', 'TeamID'])
    test_df = test_df.rename(index=str, columns={"MeanSpread": "Team2MeanSpread", "StdSpread": "Team2StdSpread", "ExpoSpread": "Team2ExpoSpread"})
    test_df = test_df.drop(['TeamID'], axis=1)
    
    test_df['Team1NormMeanSpread'] = (test_df['Team1MeanSpread'] - spread_mean_mu) / spread_mean_sigma
    test_df['Team2NormMeanSpread'] = (test_df['Team2MeanSpread'] - spread_mean_mu) / spread_mean_sigma
    test_df['Team1NormStdSpread'] = (test_df['Team1StdSpread'] - spread_std_mu) / spread_std_sigma
    test_df['Team2NormStdSpread'] = (test_df['Team2StdSpread'] - spread_std_mu) / spread_std_sigma
    test_df['Team1NormExpSpread'] = (test_df['Team1ExpoSpread'] - spread_expo_mu) / spread_expo_sigma
    test_df['Team2NormExpSpread'] = (test_df['Team2ExpoSpread'] - spread_expo_mu) / spread_expo_sigma
    
    return test_df

from keras.layers import BatchNormalization
from keras.regularizers import l2

def build_normed_deep_model(input_features, do_level=0.5, l2_lambda=0.01):
    model = Sequential()
    model.add(Dense(128, input_dim=input_features, kernel_regularizer=l2(l2_lambda)))
    model.add(BatchNormalization())
    model.add(Activation('relu'))
    model.add(Dropout(do_level))
    model.add(Dense(128, kernel_regularizer=l2(l2_lambda)))
    model.add(BatchNormalization())
    model.add(Activation('relu'))
    model.add(Dropout(do_level))
    model.add(Dense(1))
    model.add(Activation('sigmoid'))
    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
    return model

def train_normed_deep_model(training_df, epoch_count=500):
    features = [
        'NormalizedSeedDelta','Team1NormedScore','Team2NormedScore','Team1NormedSeed','Team2NormedSeed',
        'Team1NormMeanSpread','Team2NormMeanSpread','Team1NormStdSpread','Team2NormStdSpread',
        'Team1NormExpSpread','Team2NormExpSpread'
    ]
    x_train = training_df[features].values
    y_train = np.vectorize(lambda x: 1 if x else 0)(training_df['Team1Win'].values)
    x_train = x_train.reshape(len(x_train), len(features))
    y_train = y_train.reshape(len(y_train), )
    model = build_normed_deep_model(len(features))
    model.fit(x_train, y_train, epochs=epoch_count, batch_size=len(x_train), verbose=2, validation_split=0.1)
    return model

def score_normed_deep_model(training_df, model):
    features = [
        'NormalizedSeedDelta','Team1NormedScore','Team2NormedScore','Team1NormedSeed','Team2NormedSeed',
        'Team1NormMeanSpread','Team2NormMeanSpread','Team1NormStdSpread','Team2NormStdSpread',
        'Team1NormExpSpread','Team2NormExpSpread'
    ]
    x_train = training_df[features].values
    y_train = np.vectorize(lambda x: 1 if x else 0)(training_df['Team1Win'].values)
    x_train = x_train.reshape(len(x_train), len(features))
    y_train = y_train.reshape(len(y_train), )
    return model.evaluate(x_train, y_train)

def predict_with_normed_deep_model(test_df, model):
    features = [
        'NormalizedSeedDelta','Team1NormedScore','Team2NormedScore','Team1NormedSeed','Team2NormedSeed',
        'Team1NormMeanSpread','Team2NormMeanSpread','Team1NormStdSpread','Team2NormStdSpread',
        'Team1NormExpSpread','Team2NormExpSpread'
    ]
    test_x = test_df[features].values
    test_x.reshape(len(test_x), len(features))
    predictions = model.predict(test_x)[:, 0]
    return predictions

# %%
spreads_df = calculate_spreads(season_results)
# Out:
# /Users/ethan/anaconda/envs/kaggle/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
training_set, meta = training_set_with_spreads(tourney_results, seeds,season_results,spreads_df)
# Out:
# /Users/ethan/anaconda/envs/kaggle/lib/python3.6/site-packages/ipykernel_launcher.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/ethan/anaconda/envs/kaggle/lib/python3.6/site-packages/ipykernel_launcher.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/ethan/anaconda/envs/kaggle/lib/python3.6/site-packages/ipykernel_launcher.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
model = train_normed_deep_model(training_set)
# Out:
# Train on 1134 samples, validate on 126 samples
# Epoch 1/500
#  - 2s - loss: 2.4385 - acc: 0.4568 - val_loss: 2.1604 - val_acc: 0.5952
# Epoch 2/500
#  - 0s - loss: 2.3701 - acc: 0.4912 - val_loss: 2.0794 - val_acc: 0.6667
# Epoch 3/500
#  - 0s - loss: 2.2404 - acc: 0.5679 - val_loss: 2.0216 - val_acc: 0.6984
# Epoch 4/500
#  - 0s - loss: 2.1331 - acc: 0.6235 - val_loss: 1.9778 - val_acc: 0.7381
# Epoch 5/500
#  - 0s - loss: 2.1013 - acc: 0.6384 - val_loss: 1.9456 - val_acc: 0.7540
# Epoch 6/500
#  - 0s - loss: 2.0410 - acc: 0.6746 - val_loss: 1.9220 - val_acc: 0.7857
# Epoch 7/500
#  - 0s - loss: 2.0058 - acc: 0.7116 - val_loss: 1.9031 - val_acc: 0.8016
# Epoch 8/500
#  - 0s - loss: 1.9779 - acc: 0.7302 - val_loss: 1.8880 - val_acc: 0.8095
# Epoch 9/500
#  - 0s - loss: 1.9582 - acc: 0.7319 - val_loss: 1.8746 - val_acc: 0.8095
# Epoch 10/500
#  - 0s - loss: 1.9383 - acc: 0.7390 - val_loss: 1.8623 - val_acc: 0.8095
# Epoch 11/500
#  - 0s - loss: 1.9352 - acc: 0.7328 - val_loss: 1.8499 - val_acc: 0.8254
# Epoch 12/500
#  - 0s - loss: 1.9063 - acc: 0.7416 - val_loss: 1.8374 - val_acc: 0.8175
# Epoch 13/500
#  - 0s - loss: 1.8770 - acc: 0.7460 - val_loss: 1.8245 - val_acc: 0.8175
# Epoch 14/500
#  - 0s - loss: 1.8630 - acc: 0.7716 - val_loss: 1.8113 - val_acc: 0.8095
# Epoch 15/500
#  - 0s - loss: 1.8649 - acc: 0.7513 - val_loss: 1.7977 - val_acc: 0.8095
# Epoch 16/500
#  - 0s - loss: 1.8340 - acc: 0.7584 - val_loss: 1.7833 - val_acc: 0.8095
# Epoch 17/500
#  - 0s - loss: 1.8153 - acc: 0.7663 - val_loss: 1.7685 - val_acc: 0.8095
# Epoch 18/500
#  - 0s - loss: 1.7908 - acc: 0.7654 - val_loss: 1.7533 - val_acc: 0.8095
# Epoch 19/500
#  - 0s - loss: 1.7783 - acc: 0.7690 - val_loss: 1.7377 - val_acc: 0.8095
# Epoch 20/500
#  - 0s - loss: 1.7460 - acc: 0.7804 - val_loss: 1.7216 - val_acc: 0.8095
# Epoch 21/500
#  - 0s - loss: 1.7636 - acc: 0.7743 - val_loss: 1.7055 - val_acc: 0.8095
# Epoch 22/500
#  - 0s - loss: 1.7160 - acc: 0.7751 - val_loss: 1.6891 - val_acc: 0.8095
# Epoch 23/500
#  - 0s - loss: 1.7321 - acc: 0.7707 - val_loss: 1.6726 - val_acc: 0.8095
# Epoch 24/500
#  - 0s - loss: 1.6926 - acc: 0.7751 - val_loss: 1.6563 - val_acc: 0.8016
# Epoch 25/500
#  - 0s - loss: 1.6747 - acc: 0.7654 - val_loss: 1.6399 - val_acc: 0.8016
# Epoch 26/500
#  - 0s - loss: 1.6785 - acc: 0.7610 - val_loss: 1.6238 - val_acc: 0.8016
# Epoch 27/500
#  - 0s - loss: 1.6408 - acc: 0.7663 - val_loss: 1.6078 - val_acc: 0.8016
# Epoch 28/500
#  - 0s - loss: 1.6032 - acc: 0.7698 - val_loss: 1.5920 - val_acc: 0.7937
# Epoch 29/500
#  - 0s - loss: 1.6067 - acc: 0.7769 - val_loss: 1.5764 - val_acc: 0.7937
# Epoch 30/500
#  - 0s - loss: 1.5934 - acc: 0.7610 - val_loss: 1.5608 - val_acc: 0.7937
# Epoch 31/500
#  - 0s - loss: 1.5786 - acc: 0.7734 - val_loss: 1.5453 - val_acc: 0.7857
# Epoch 32/500
#  - 0s - loss: 1.5654 - acc: 0.7857 - val_loss: 1.5298 - val_acc: 0.7778
# Epoch 33/500
#  - 0s - loss: 1.5544 - acc: 0.7637 - val_loss: 1.5146 - val_acc: 0.7778
# Epoch 34/500
#  - 0s - loss: 1.5253 - acc: 0.7672 - val_loss: 1.4996 - val_acc: 0.7778
# Epoch 35/500
#  - 0s - loss: 1.5127 - acc: 0.7672 - val_loss: 1.4849 - val_acc: 0.7778
# Epoch 36/500
#  - 0s - loss: 1.5083 - acc: 0.7610 - val_loss: 1.4702 - val_acc: 0.7778
# Epoch 37/500
#  - 0s - loss: 1.4878 - acc: 0.7681 - val_loss: 1.4557 - val_acc: 0.7857
# Epoch 38/500
#  - 0s - loss: 1.4868 - acc: 0.7663 - val_loss: 1.4415 - val_acc: 0.7857
# Epoch 39/500
#  - 0s - loss: 1.4483 - acc: 0.7769 - val_loss: 1.4273 - val_acc: 0.7857
# Epoch 40/500
#  - 0s - loss: 1.4400 - acc: 0.7672 - val_loss: 1.4136 - val_acc: 0.7857
# Epoch 41/500
#  - 0s - loss: 1.4188 - acc: 0.7769 - val_loss: 1.4001 - val_acc: 0.7698
# Epoch 42/500
#  - 0s - loss: 1.3973 - acc: 0.7663 - val_loss: 1.3868 - val_acc: 0.7698
# Epoch 43/500
#  - 0s - loss: 1.4004 - acc: 0.7751 - val_loss: 1.3737 - val_acc: 0.7698
# Epoch 44/500
#  - 0s - loss: 1.3681 - acc: 0.7760 - val_loss: 1.3607 - val_acc: 0.7619
# Epoch 45/500
#  - 0s - loss: 1.3746 - acc: 0.7672 - val_loss: 1.3479 - val_acc: 0.7619
# Epoch 46/500
#  - 0s - loss: 1.3558 - acc: 0.7751 - val_loss: 1.3354 - val_acc: 0.7619
# Epoch 47/500
#  - 0s - loss: 1.3589 - acc: 0.7707 - val_loss: 1.3230 - val_acc: 0.7619
# Epoch 48/500
#  - 0s - loss: 1.3260 - acc: 0.7646 - val_loss: 1.3107 - val_acc: 0.7619
# Epoch 49/500
#  - 0s - loss: 1.3095 - acc: 0.7672 - val_loss: 1.2986 - val_acc: 0.7619
# Epoch 50/500
#  - 0s - loss: 1.3036 - acc: 0.7716 - val_loss: 1.2867 - val_acc: 0.7619
# Epoch 51/500
#  - 0s - loss: 1.2897 - acc: 0.7725 - val_loss: 1.2748 - val_acc: 0.7619
# Epoch 52/500
#  - 0s - loss: 1.2739 - acc: 0.7804 - val_loss: 1.2632 - val_acc: 0.7619
# Epoch 53/500
#  - 0s - loss: 1.2591 - acc: 0.7681 - val_loss: 1.2516 - val_acc: 0.7619
# Epoch 54/500
#  - 0s - loss: 1.2501 - acc: 0.7787 - val_loss: 1.2402 - val_acc: 0.7619
# Epoch 55/500
#  - 0s - loss: 1.2529 - acc: 0.7725 - val_loss: 1.2289 - val_acc: 0.7619
# Epoch 56/500
#  - 0s - loss: 1.2344 - acc: 0.7778 - val_loss: 1.2177 - val_acc: 0.7619
# Epoch 57/500
#  - 0s - loss: 1.2162 - acc: 0.7751 - val_loss: 1.2066 - val_acc: 0.7619
# Epoch 58/500
#  - 0s - loss: 1.2047 - acc: 0.7575 - val_loss: 1.1956 - val_acc: 0.7619
# Epoch 59/500
#  - 0s - loss: 1.1919 - acc: 0.7778 - val_loss: 1.1848 - val_acc: 0.7619
# Epoch 60/500
#  - 0s - loss: 1.1804 - acc: 0.7831 - val_loss: 1.1743 - val_acc: 0.7619
# Epoch 61/500
#  - 0s - loss: 1.1609 - acc: 0.7743 - val_loss: 1.1641 - val_acc: 0.7619
# Epoch 62/500
#  - 0s - loss: 1.1641 - acc: 0.7751 - val_loss: 1.1539 - val_acc: 0.7619
# Epoch 63/500
#  - 0s - loss: 1.1650 - acc: 0.7575 - val_loss: 1.1439 - val_acc: 0.7619
# Epoch 64/500
#  - 0s - loss: 1.1618 - acc: 0.7778 - val_loss: 1.1340 - val_acc: 0.7619
# Epoch 65/500
#  - 0s - loss: 1.1270 - acc: 0.7804 - val_loss: 1.1242 - val_acc: 0.7619
# Epoch 66/500
#  - 0s - loss: 1.1213 - acc: 0.7795 - val_loss: 1.1146 - val_acc: 0.7619
# Epoch 67/500
#  - 0s - loss: 1.1091 - acc: 0.7804 - val_loss: 1.1051 - val_acc: 0.7619
# Epoch 68/500
#  - 0s - loss: 1.0940 - acc: 0.7725 - val_loss: 1.0958 - val_acc: 0.7619
# Epoch 69/500
#  - 0s - loss: 1.0890 - acc: 0.7884 - val_loss: 1.0866 - val_acc: 0.7619
# Epoch 70/500
#  - 0s - loss: 1.0757 - acc: 0.7822 - val_loss: 1.0775 - val_acc: 0.7540
# Epoch 71/500
#  - 0s - loss: 1.0723 - acc: 0.7795 - val_loss: 1.0686 - val_acc: 0.7540
# Epoch 72/500
#  - 0s - loss: 1.0729 - acc: 0.7769 - val_loss: 1.0598 - val_acc: 0.7540
# Epoch 73/500
#  - 0s - loss: 1.0555 - acc: 0.7628 - val_loss: 1.0510 - val_acc: 0.7460
# Epoch 74/500
#  - 0s - loss: 1.0388 - acc: 0.7698 - val_loss: 1.0425 - val_acc: 0.7460
# Epoch 75/500
#  - 0s - loss: 1.0303 - acc: 0.7769 - val_loss: 1.0341 - val_acc: 0.7460
# Epoch 76/500
#  - 0s - loss: 1.0116 - acc: 0.7840 - val_loss: 1.0259 - val_acc: 0.7460
# Epoch 77/500
#  - 0s - loss: 1.0016 - acc: 0.7813 - val_loss: 1.0178 - val_acc: 0.7460
# Epoch 78/500
#  - 0s - loss: 1.0182 - acc: 0.7795 - val_loss: 1.0097 - val_acc: 0.7460
# Epoch 79/500
#  - 0s - loss: 1.0000 - acc: 0.7760 - val_loss: 1.0017 - val_acc: 0.7460
# Epoch 80/500
#  - 0s - loss: 0.9964 - acc: 0.7646 - val_loss: 0.9938 - val_acc: 0.7460
# Epoch 81/500
#  - 0s - loss: 0.9691 - acc: 0.7972 - val_loss: 0.9861 - val_acc: 0.7460
# Epoch 82/500
#  - 0s - loss: 0.9725 - acc: 0.7751 - val_loss: 0.9787 - val_acc: 0.7460
# Epoch 83/500
#  - 0s - loss: 0.9550 - acc: 0.7813 - val_loss: 0.9713 - val_acc: 0.7460
# Epoch 84/500
#  - 0s - loss: 0.9531 - acc: 0.7787 - val_loss: 0.9641 - val_acc: 0.7460
# Epoch 85/500
#  - 0s - loss: 0.9467 - acc: 0.7804 - val_loss: 0.9568 - val_acc: 0.7460
# Epoch 86/500
#  - 0s - loss: 0.9306 - acc: 0.7787 - val_loss: 0.9496 - val_acc: 0.7460
# Epoch 87/500
#  - 0s - loss: 0.9322 - acc: 0.7866 - val_loss: 0.9425 - val_acc: 0.7460
# Epoch 88/500
#  - 0s - loss: 0.9203 - acc: 0.7787 - val_loss: 0.9356 - val_acc: 0.7540
# Epoch 89/500
#  - 0s - loss: 0.9122 - acc: 0.7725 - val_loss: 0.9286 - val_acc: 0.7460
# Epoch 90/500
#  - 0s - loss: 0.9112 - acc: 0.7840 - val_loss: 0.9217 - val_acc: 0.7460
# Epoch 91/500
#  - 0s - loss: 0.9109 - acc: 0.7813 - val_loss: 0.9150 - val_acc: 0.7460
# Epoch 92/500
#  - 0s - loss: 0.8870 - acc: 0.7901 - val_loss: 0.9083 - val_acc: 0.7460
# Epoch 93/500
#  - 0s - loss: 0.8864 - acc: 0.7760 - val_loss: 0.9016 - val_acc: 0.7460
# Epoch 94/500
#  - 0s - loss: 0.8658 - acc: 0.7813 - val_loss: 0.8952 - val_acc: 0.7540
# Epoch 95/500
#  - 0s - loss: 0.8659 - acc: 0.7910 - val_loss: 0.8889 - val_acc: 0.7540
# Epoch 96/500
#  - 0s - loss: 0.8576 - acc: 0.7769 - val_loss: 0.8826 - val_acc: 0.7540
# Epoch 97/500
#  - 0s - loss: 0.8624 - acc: 0.7778 - val_loss: 0.8765 - val_acc: 0.7540
# Epoch 98/500
#  - 0s - loss: 0.8535 - acc: 0.7831 - val_loss: 0.8705 - val_acc: 0.7619
# Epoch 99/500
#  - 0s - loss: 0.8450 - acc: 0.7698 - val_loss: 0.8645 - val_acc: 0.7619
# Epoch 100/500
#  - 0s - loss: 0.8290 - acc: 0.7875 - val_loss: 0.8587 - val_acc: 0.7540
# Epoch 101/500
#  - 0s - loss: 0.8387 - acc: 0.7795 - val_loss: 0.8531 - val_acc: 0.7540
# Epoch 102/500
#  - 0s - loss: 0.8178 - acc: 0.7813 - val_loss: 0.8475 - val_acc: 0.7540
# Epoch 103/500
#  - 0s - loss: 0.8436 - acc: 0.7690 - val_loss: 0.8420 - val_acc: 0.7540
# Epoch 104/500
#  - 0s - loss: 0.8073 - acc: 0.7884 - val_loss: 0.8366 - val_acc: 0.7540
# Epoch 105/500
#  - 0s - loss: 0.8184 - acc: 0.7875 - val_loss: 0.8314 - val_acc: 0.7540
# Epoch 106/500
#  - 0s - loss: 0.8060 - acc: 0.7848 - val_loss: 0.8262 - val_acc: 0.7540
# Epoch 107/500
#  - 0s - loss: 0.7936 - acc: 0.7954 - val_loss: 0.8211 - val_acc: 0.7540
# Epoch 108/500
#  - 0s - loss: 0.7809 - acc: 0.7857 - val_loss: 0.8162 - val_acc: 0.7540
# Epoch 109/500
#  - 0s - loss: 0.7846 - acc: 0.7866 - val_loss: 0.8116 - val_acc: 0.7540
# Epoch 110/500
#  - 0s - loss: 0.7954 - acc: 0.7875 - val_loss: 0.8069 - val_acc: 0.7540
# Epoch 111/500
#  - 0s - loss: 0.7813 - acc: 0.7734 - val_loss: 0.8024 - val_acc: 0.7540
# Epoch 112/500
#  - 0s - loss: 0.7601 - acc: 0.7910 - val_loss: 0.7980 - val_acc: 0.7540
# Epoch 113/500
#  - 0s - loss: 0.7642 - acc: 0.7787 - val_loss: 0.7938 - val_acc: 0.7540
# Epoch 114/500
#  - 0s - loss: 0.7870 - acc: 0.7795 - val_loss: 0.7898 - val_acc: 0.7540
# Epoch 115/500
#  - 0s - loss: 0.7518 - acc: 0.7875 - val_loss: 0.7859 - val_acc: 0.7540
# Epoch 116/500
#  - 0s - loss: 0.7459 - acc: 0.7901 - val_loss: 0.7821 - val_acc: 0.7540
# Epoch 117/500
#  - 0s - loss: 0.7465 - acc: 0.7848 - val_loss: 0.7785 - val_acc: 0.7460
# Epoch 118/500
#  - 0s - loss: 0.7358 - acc: 0.7901 - val_loss: 0.7748 - val_acc: 0.7381
# Epoch 119/500
#  - 0s - loss: 0.7329 - acc: 0.7884 - val_loss: 0.7712 - val_acc: 0.7540
# Epoch 120/500
#  - 0s - loss: 0.7268 - acc: 0.7954 - val_loss: 0.7678 - val_acc: 0.7540
# Epoch 121/500
#  - 0s - loss: 0.7277 - acc: 0.7866 - val_loss: 0.7644 - val_acc: 0.7540
# Epoch 122/500
#  - 0s - loss: 0.7204 - acc: 0.7937 - val_loss: 0.7609 - val_acc: 0.7540
# Epoch 123/500
#  - 0s - loss: 0.7128 - acc: 0.7919 - val_loss: 0.7575 - val_acc: 0.7540
# Epoch 124/500
#  - 0s - loss: 0.7177 - acc: 0.7840 - val_loss: 0.7540 - val_acc: 0.7540
# Epoch 125/500
#  - 0s - loss: 0.6954 - acc: 0.7972 - val_loss: 0.7506 - val_acc: 0.7460
# Epoch 126/500
#  - 0s - loss: 0.7026 - acc: 0.7892 - val_loss: 0.7474 - val_acc: 0.7460
# Epoch 127/500
#  - 0s - loss: 0.7068 - acc: 0.7848 - val_loss: 0.7439 - val_acc: 0.7460
# Epoch 128/500
#  - 0s - loss: 0.6971 - acc: 0.7866 - val_loss: 0.7407 - val_acc: 0.7460
# Epoch 129/500
#  - 0s - loss: 0.6788 - acc: 0.7998 - val_loss: 0.7376 - val_acc: 0.7460
# Epoch 130/500
#  - 0s - loss: 0.6914 - acc: 0.7840 - val_loss: 0.7347 - val_acc: 0.7460
# Epoch 131/500
#  - 0s - loss: 0.6956 - acc: 0.7857 - val_loss: 0.7318 - val_acc: 0.7460
# Epoch 132/500
#  - 0s - loss: 0.6734 - acc: 0.7857 - val_loss: 0.7288 - val_acc: 0.7460
# Epoch 133/500
#  - 0s - loss: 0.6920 - acc: 0.7937 - val_loss: 0.7257 - val_acc: 0.7460
# Epoch 134/500
#  - 0s - loss: 0.6586 - acc: 0.7848 - val_loss: 0.7228 - val_acc: 0.7460
# Epoch 135/500
#  - 0s - loss: 0.6723 - acc: 0.7919 - val_loss: 0.7203 - val_acc: 0.7460
# Epoch 136/500
#  - 0s - loss: 0.6536 - acc: 0.7981 - val_loss: 0.7174 - val_acc: 0.7460
# Epoch 137/500
#  - 0s - loss: 0.6516 - acc: 0.7919 - val_loss: 0.7145 - val_acc: 0.7460
# Epoch 138/500
#  - 0s - loss: 0.6535 - acc: 0.7919 - val_loss: 0.7117 - val_acc: 0.7460
# Epoch 139/500
#  - 0s - loss: 0.6622 - acc: 0.7840 - val_loss: 0.7090 - val_acc: 0.7540
# Epoch 140/500
#  - 0s - loss: 0.6558 - acc: 0.8034 - val_loss: 0.7067 - val_acc: 0.7540
# Epoch 141/500
#  - 0s - loss: 0.6351 - acc: 0.7981 - val_loss: 0.7046 - val_acc: 0.7540
# Epoch 142/500
#  - 0s - loss: 0.6464 - acc: 0.7840 - val_loss: 0.7025 - val_acc: 0.7540
# Epoch 143/500
#  - 0s - loss: 0.6434 - acc: 0.7989 - val_loss: 0.7004 - val_acc: 0.7540
# Epoch 144/500
#  - 0s - loss: 0.6360 - acc: 0.7928 - val_loss: 0.6987 - val_acc: 0.7540
# Epoch 145/500
#  - 0s - loss: 0.6188 - acc: 0.7919 - val_loss: 0.6973 - val_acc: 0.7540
# Epoch 146/500
#  - 0s - loss: 0.6147 - acc: 0.7989 - val_loss: 0.6962 - val_acc: 0.7540
# Epoch 147/500
#  - 0s - loss: 0.6423 - acc: 0.7884 - val_loss: 0.6948 - val_acc: 0.7460
# Epoch 148/500
#  - 0s - loss: 0.6198 - acc: 0.7910 - val_loss: 0.6932 - val_acc: 0.7460
# Epoch 149/500
#  - 0s - loss: 0.6169 - acc: 0.7954 - val_loss: 0.6918 - val_acc: 0.7460
# Epoch 150/500
#  - 0s - loss: 0.6136 - acc: 0.8034 - val_loss: 0.6902 - val_acc: 0.7381
# Epoch 151/500
#  - 0s - loss: 0.6222 - acc: 0.7998 - val_loss: 0.6887 - val_acc: 0.7381
# Epoch 152/500
#  - 0s - loss: 0.6102 - acc: 0.7954 - val_loss: 0.6872 - val_acc: 0.7381
# Epoch 153/500
#  - 0s - loss: 0.6096 - acc: 0.7840 - val_loss: 0.6854 - val_acc: 0.7381
# Epoch 154/500
#  - 0s - loss: 0.6016 - acc: 0.8025 - val_loss: 0.6832 - val_acc: 0.7381
# Epoch 155/500
#  - 0s - loss: 0.6083 - acc: 0.7910 - val_loss: 0.6811 - val_acc: 0.7381
# Epoch 156/500
#  - 0s - loss: 0.5969 - acc: 0.8025 - val_loss: 0.6793 - val_acc: 0.7381
# Epoch 157/500
#  - 0s - loss: 0.6019 - acc: 0.7954 - val_loss: 0.6776 - val_acc: 0.7460
# Epoch 158/500
#  - 0s - loss: 0.5931 - acc: 0.7954 - val_loss: 0.6757 - val_acc: 0.7460
# Epoch 159/500
#  - 0s - loss: 0.5904 - acc: 0.7981 - val_loss: 0.6736 - val_acc: 0.7460
# Epoch 160/500
#  - 0s - loss: 0.5864 - acc: 0.7954 - val_loss: 0.6717 - val_acc: 0.7381
# Epoch 161/500
#  - 0s - loss: 0.5843 - acc: 0.8025 - val_loss: 0.6701 - val_acc: 0.7381
# Epoch 162/500
#  - 0s - loss: 0.5892 - acc: 0.7822 - val_loss: 0.6686 - val_acc: 0.7381
# Epoch 163/500
#  - 0s - loss: 0.5870 - acc: 0.7954 - val_loss: 0.6670 - val_acc: 0.7381
# Epoch 164/500
#  - 0s - loss: 0.5712 - acc: 0.7998 - val_loss: 0.6655 - val_acc: 0.7381
# Epoch 165/500
#  - 0s - loss: 0.5710 - acc: 0.7901 - val_loss: 0.6643 - val_acc: 0.7381
# Epoch 166/500
#  - 0s - loss: 0.5739 - acc: 0.7866 - val_loss: 0.6632 - val_acc: 0.7381
# Epoch 167/500
#  - 0s - loss: 0.5817 - acc: 0.7804 - val_loss: 0.6625 - val_acc: 0.7302
# Epoch 168/500
#  - 0s - loss: 0.5742 - acc: 0.7892 - val_loss: 0.6621 - val_acc: 0.7302
# Epoch 169/500
#  - 0s - loss: 0.5602 - acc: 0.7981 - val_loss: 0.6618 - val_acc: 0.7381
# Epoch 170/500
#  - 0s - loss: 0.5663 - acc: 0.7919 - val_loss: 0.6613 - val_acc: 0.7381
# Epoch 171/500
#  - 0s - loss: 0.5495 - acc: 0.8069 - val_loss: 0.6609 - val_acc: 0.7381
# Epoch 172/500
#  - 0s - loss: 0.5673 - acc: 0.8007 - val_loss: 0.6607 - val_acc: 0.7381
# Epoch 173/500
#  - 0s - loss: 0.5585 - acc: 0.8060 - val_loss: 0.6610 - val_acc: 0.7381
# Epoch 174/500
#  - 0s - loss: 0.5496 - acc: 0.7989 - val_loss: 0.6613 - val_acc: 0.7302
# Epoch 175/500
#  - 0s - loss: 0.5624 - acc: 0.7989 - val_loss: 0.6614 - val_acc: 0.7302
# Epoch 176/500
#  - 0s - loss: 0.5613 - acc: 0.8007 - val_loss: 0.6613 - val_acc: 0.7460
# Epoch 177/500
#  - 0s - loss: 0.5431 - acc: 0.7928 - val_loss: 0.6605 - val_acc: 0.7460
# Epoch 178/500
#  - 0s - loss: 0.5555 - acc: 0.7963 - val_loss: 0.6594 - val_acc: 0.7460
# Epoch 179/500
#  - 0s - loss: 0.5527 - acc: 0.7928 - val_loss: 0.6580 - val_acc: 0.7381
# Epoch 180/500
#  - 0s - loss: 0.5399 - acc: 0.8016 - val_loss: 0.6568 - val_acc: 0.7381
# Epoch 181/500
#  - 0s - loss: 0.5385 - acc: 0.7989 - val_loss: 0.6554 - val_acc: 0.7381
# Epoch 182/500
#  - 0s - loss: 0.5398 - acc: 0.7910 - val_loss: 0.6543 - val_acc: 0.7381
# Epoch 183/500
#  - 0s - loss: 0.5413 - acc: 0.8060 - val_loss: 0.6538 - val_acc: 0.7381
# Epoch 184/500
#  - 0s - loss: 0.5392 - acc: 0.7945 - val_loss: 0.6535 - val_acc: 0.7222
# Epoch 185/500
#  - 0s - loss: 0.5322 - acc: 0.7989 - val_loss: 0.6532 - val_acc: 0.7222
# Epoch 186/500
#  - 0s - loss: 0.5431 - acc: 0.7937 - val_loss: 0.6527 - val_acc: 0.7222
# Epoch 187/500
#  - 0s - loss: 0.5338 - acc: 0.8051 - val_loss: 0.6519 - val_acc: 0.7222
# Epoch 188/500
#  - 0s - loss: 0.5335 - acc: 0.7981 - val_loss: 0.6513 - val_acc: 0.7222
# Epoch 189/500
#  - 0s - loss: 0.5341 - acc: 0.7910 - val_loss: 0.6505 - val_acc: 0.7222
# Epoch 190/500
#  - 0s - loss: 0.5324 - acc: 0.8060 - val_loss: 0.6503 - val_acc: 0.7381
# Epoch 191/500
#  - 0s - loss: 0.5214 - acc: 0.7989 - val_loss: 0.6497 - val_acc: 0.7381
# Epoch 192/500
#  - 0s - loss: 0.5247 - acc: 0.8060 - val_loss: 0.6490 - val_acc: 0.7381
# Epoch 193/500
#  - 0s - loss: 0.5274 - acc: 0.7892 - val_loss: 0.6487 - val_acc: 0.7381
# Epoch 194/500
#  - 0s - loss: 0.5221 - acc: 0.8113 - val_loss: 0.6491 - val_acc: 0.7381
# Epoch 195/500
#  - 0s - loss: 0.5168 - acc: 0.7998 - val_loss: 0.6495 - val_acc: 0.7381
# Epoch 196/500
#  - 0s - loss: 0.5187 - acc: 0.7945 - val_loss: 0.6500 - val_acc: 0.7381
# Epoch 197/500
#  - 0s - loss: 0.5175 - acc: 0.8034 - val_loss: 0.6507 - val_acc: 0.7460
# Epoch 198/500
#  - 0s - loss: 0.5254 - acc: 0.7892 - val_loss: 0.6511 - val_acc: 0.7460
# Epoch 199/500
#  - 0s - loss: 0.5173 - acc: 0.7928 - val_loss: 0.6509 - val_acc: 0.7460
# Epoch 200/500
#  - 0s - loss: 0.5240 - acc: 0.7981 - val_loss: 0.6511 - val_acc: 0.7460
# Epoch 201/500
#  - 0s - loss: 0.5213 - acc: 0.8016 - val_loss: 0.6510 - val_acc: 0.7381
# Epoch 202/500
#  - 0s - loss: 0.5040 - acc: 0.8069 - val_loss: 0.6508 - val_acc: 0.7381
# Epoch 203/500
#  - 0s - loss: 0.5106 - acc: 0.8025 - val_loss: 0.6503 - val_acc: 0.7381
# Epoch 204/500
#  - 0s - loss: 0.5128 - acc: 0.7989 - val_loss: 0.6495 - val_acc: 0.7381
# Epoch 205/500
#  - 0s - loss: 0.5095 - acc: 0.7919 - val_loss: 0.6487 - val_acc: 0.7381
# Epoch 206/500
#  - 0s - loss: 0.5030 - acc: 0.8025 - val_loss: 0.6485 - val_acc: 0.7381
# Epoch 207/500
#  - 0s - loss: 0.4986 - acc: 0.7972 - val_loss: 0.6484 - val_acc: 0.7460
# Epoch 208/500
#  - 0s - loss: 0.5011 - acc: 0.8095 - val_loss: 0.6482 - val_acc: 0.7460
# Epoch 209/500
#  - 0s - loss: 0.4875 - acc: 0.7972 - val_loss: 0.6484 - val_acc: 0.7460
# Epoch 210/500
#  - 0s - loss: 0.4881 - acc: 0.8060 - val_loss: 0.6490 - val_acc: 0.7381
# Epoch 211/500
#  - 0s - loss: 0.4934 - acc: 0.8016 - val_loss: 0.6490 - val_acc: 0.7381
# Epoch 212/500
#  - 0s - loss: 0.4982 - acc: 0.8131 - val_loss: 0.6490 - val_acc: 0.7381
# Epoch 213/500
#  - 0s - loss: 0.4893 - acc: 0.7937 - val_loss: 0.6499 - val_acc: 0.7381
# Epoch 214/500
#  - 0s - loss: 0.5034 - acc: 0.8016 - val_loss: 0.6513 - val_acc: 0.7381
# Epoch 215/500
#  - 0s - loss: 0.4889 - acc: 0.8104 - val_loss: 0.6521 - val_acc: 0.7381
# Epoch 216/500
#  - 0s - loss: 0.4882 - acc: 0.7937 - val_loss: 0.6522 - val_acc: 0.7460
# Epoch 217/500
#  - 0s - loss: 0.4889 - acc: 0.8042 - val_loss: 0.6526 - val_acc: 0.7460
# Epoch 218/500
#  - 0s - loss: 0.4899 - acc: 0.8078 - val_loss: 0.6527 - val_acc: 0.7381
# Epoch 219/500
#  - 0s - loss: 0.4823 - acc: 0.8078 - val_loss: 0.6526 - val_acc: 0.7381
# Epoch 220/500
#  - 0s - loss: 0.4808 - acc: 0.8069 - val_loss: 0.6526 - val_acc: 0.7381
# Epoch 221/500
#  - 0s - loss: 0.4893 - acc: 0.8016 - val_loss: 0.6525 - val_acc: 0.7381
# Epoch 222/500
#  - 0s - loss: 0.4799 - acc: 0.8069 - val_loss: 0.6524 - val_acc: 0.7381
# Epoch 223/500
#  - 0s - loss: 0.4811 - acc: 0.8034 - val_loss: 0.6529 - val_acc: 0.7381
# Epoch 224/500
#  - 0s - loss: 0.4772 - acc: 0.8086 - val_loss: 0.6532 - val_acc: 0.7460
# Epoch 225/500
#  - 0s - loss: 0.4706 - acc: 0.8060 - val_loss: 0.6542 - val_acc: 0.7619
# Epoch 226/500
#  - 0s - loss: 0.4762 - acc: 0.8157 - val_loss: 0.6550 - val_acc: 0.7619
# Epoch 227/500
#  - 0s - loss: 0.4810 - acc: 0.8042 - val_loss: 0.6559 - val_acc: 0.7540
# Epoch 228/500
#  - 0s - loss: 0.4859 - acc: 0.8034 - val_loss: 0.6568 - val_acc: 0.7540
# Epoch 229/500
#  - 0s - loss: 0.4736 - acc: 0.8034 - val_loss: 0.6573 - val_acc: 0.7540
# Epoch 230/500
#  - 0s - loss: 0.4672 - acc: 0.8131 - val_loss: 0.6571 - val_acc: 0.7619
# Epoch 231/500
#  - 0s - loss: 0.4869 - acc: 0.8025 - val_loss: 0.6564 - val_acc: 0.7619
# Epoch 232/500
#  - 0s - loss: 0.4757 - acc: 0.8042 - val_loss: 0.6551 - val_acc: 0.7619
# Epoch 233/500
#  - 0s - loss: 0.4701 - acc: 0.7998 - val_loss: 0.6536 - val_acc: 0.7619
# Epoch 234/500
#  - 0s - loss: 0.4705 - acc: 0.8007 - val_loss: 0.6522 - val_acc: 0.7698
# Epoch 235/500
#  - 0s - loss: 0.4623 - acc: 0.8113 - val_loss: 0.6514 - val_acc: 0.7698
# Epoch 236/500
#  - 0s - loss: 0.4637 - acc: 0.8069 - val_loss: 0.6511 - val_acc: 0.7698
# Epoch 237/500
#  - 0s - loss: 0.4784 - acc: 0.8025 - val_loss: 0.6513 - val_acc: 0.7698
# Epoch 238/500
#  - 0s - loss: 0.4700 - acc: 0.8086 - val_loss: 0.6514 - val_acc: 0.7698
# Epoch 239/500
#  - 0s - loss: 0.4683 - acc: 0.8060 - val_loss: 0.6512 - val_acc: 0.7698
# Epoch 240/500
#  - 0s - loss: 0.4683 - acc: 0.8131 - val_loss: 0.6508 - val_acc: 0.7698
# Epoch 241/500
#  - 0s - loss: 0.4641 - acc: 0.7998 - val_loss: 0.6505 - val_acc: 0.7698
# Epoch 242/500
#  - 0s - loss: 0.4591 - acc: 0.8131 - val_loss: 0.6499 - val_acc: 0.7619
# Epoch 243/500
#  - 0s - loss: 0.4623 - acc: 0.8069 - val_loss: 0.6496 - val_acc: 0.7619
# Epoch 244/500
#  - 0s - loss: 0.4573 - acc: 0.7989 - val_loss: 0.6488 - val_acc: 0.7619
# Epoch 245/500
#  - 0s - loss: 0.4594 - acc: 0.8016 - val_loss: 0.6485 - val_acc: 0.7540
# Epoch 246/500
#  - 0s - loss: 0.4771 - acc: 0.8201 - val_loss: 0.6485 - val_acc: 0.7460
# Epoch 247/500
#  - 0s - loss: 0.4667 - acc: 0.8086 - val_loss: 0.6489 - val_acc: 0.7460
# Epoch 248/500
#  - 0s - loss: 0.4626 - acc: 0.8139 - val_loss: 0.6491 - val_acc: 0.7460
# Epoch 249/500
#  - 0s - loss: 0.4603 - acc: 0.8139 - val_loss: 0.6488 - val_acc: 0.7540
# Epoch 250/500
#  - 0s - loss: 0.4647 - acc: 0.7998 - val_loss: 0.6487 - val_acc: 0.7540
# Epoch 251/500
#  - 0s - loss: 0.4523 - acc: 0.8060 - val_loss: 0.6480 - val_acc: 0.7540
# Epoch 252/500
#  - 0s - loss: 0.4673 - acc: 0.8078 - val_loss: 0.6478 - val_acc: 0.7540
# Epoch 253/500
#  - 0s - loss: 0.4553 - acc: 0.8113 - val_loss: 0.6483 - val_acc: 0.7540
# Epoch 254/500
#  - 0s - loss: 0.4526 - acc: 0.8086 - val_loss: 0.6489 - val_acc: 0.7460
# Epoch 255/500
#  - 0s - loss: 0.4579 - acc: 0.8148 - val_loss: 0.6495 - val_acc: 0.7540
# Epoch 256/500
#  - 0s - loss: 0.4620 - acc: 0.8122 - val_loss: 0.6501 - val_acc: 0.7540
# Epoch 257/500
#  - 0s - loss: 0.4610 - acc: 0.8095 - val_loss: 0.6499 - val_acc: 0.7460
# Epoch 258/500
#  - 0s - loss: 0.4506 - acc: 0.8060 - val_loss: 0.6496 - val_acc: 0.7381
# Epoch 259/500
#  - 0s - loss: 0.4441 - acc: 0.8148 - val_loss: 0.6494 - val_acc: 0.7460
# Epoch 260/500
#  - 0s - loss: 0.4492 - acc: 0.8210 - val_loss: 0.6500 - val_acc: 0.7460
# Epoch 261/500
#  - 0s - loss: 0.4497 - acc: 0.8183 - val_loss: 0.6498 - val_acc: 0.7540
# Epoch 262/500
#  - 0s - loss: 0.4404 - acc: 0.8148 - val_loss: 0.6502 - val_acc: 0.7619
# Epoch 263/500
#  - 0s - loss: 0.4646 - acc: 0.7998 - val_loss: 0.6513 - val_acc: 0.7540
# Epoch 264/500
#  - 0s - loss: 0.4490 - acc: 0.8078 - val_loss: 0.6532 - val_acc: 0.7540
# Epoch 265/500
#  - 0s - loss: 0.4529 - acc: 0.8025 - val_loss: 0.6564 - val_acc: 0.7460
# Epoch 266/500
#  - 0s - loss: 0.4453 - acc: 0.8131 - val_loss: 0.6600 - val_acc: 0.7540
# Epoch 267/500
#  - 0s - loss: 0.4385 - acc: 0.8139 - val_loss: 0.6629 - val_acc: 0.7381
# Epoch 268/500
#  - 0s - loss: 0.4400 - acc: 0.8113 - val_loss: 0.6647 - val_acc: 0.7460
# Epoch 269/500
#  - 0s - loss: 0.4501 - acc: 0.8139 - val_loss: 0.6650 - val_acc: 0.7381
# Epoch 270/500
#  - 0s - loss: 0.4485 - acc: 0.8122 - val_loss: 0.6646 - val_acc: 0.7302
# Epoch 271/500
#  - 0s - loss: 0.4449 - acc: 0.8025 - val_loss: 0.6643 - val_acc: 0.7302
# Epoch 272/500
#  - 0s - loss: 0.4543 - acc: 0.8183 - val_loss: 0.6636 - val_acc: 0.7222
# Epoch 273/500
#  - 0s - loss: 0.4442 - acc: 0.8122 - val_loss: 0.6626 - val_acc: 0.7302
# Epoch 274/500
#  - 0s - loss: 0.4482 - acc: 0.8263 - val_loss: 0.6628 - val_acc: 0.7381
# Epoch 275/500
#  - 0s - loss: 0.4442 - acc: 0.8016 - val_loss: 0.6622 - val_acc: 0.7540
# Epoch 276/500
#  - 0s - loss: 0.4366 - acc: 0.8166 - val_loss: 0.6618 - val_acc: 0.7540
# Epoch 277/500
#  - 0s - loss: 0.4485 - acc: 0.8166 - val_loss: 0.6613 - val_acc: 0.7540
# Epoch 278/500
#  - 0s - loss: 0.4468 - acc: 0.8166 - val_loss: 0.6617 - val_acc: 0.7619
# Epoch 279/500
#  - 0s - loss: 0.4400 - acc: 0.8201 - val_loss: 0.6625 - val_acc: 0.7619
# Epoch 280/500
#  - 0s - loss: 0.4417 - acc: 0.8219 - val_loss: 0.6617 - val_acc: 0.7619
# Epoch 281/500
#  - 0s - loss: 0.4416 - acc: 0.8157 - val_loss: 0.6610 - val_acc: 0.7540
# Epoch 282/500
#  - 0s - loss: 0.4458 - acc: 0.8051 - val_loss: 0.6610 - val_acc: 0.7460
# Epoch 283/500
#  - 0s - loss: 0.4311 - acc: 0.8263 - val_loss: 0.6613 - val_acc: 0.7302
# Epoch 284/500
#  - 0s - loss: 0.4512 - acc: 0.8025 - val_loss: 0.6616 - val_acc: 0.7222
# Epoch 285/500
#  - 0s - loss: 0.4412 - acc: 0.8034 - val_loss: 0.6612 - val_acc: 0.7222
# Epoch 286/500
#  - 0s - loss: 0.4346 - acc: 0.8078 - val_loss: 0.6605 - val_acc: 0.7222
# Epoch 287/500
#  - 0s - loss: 0.4363 - acc: 0.8192 - val_loss: 0.6591 - val_acc: 0.7302
# Epoch 288/500
#  - 0s - loss: 0.4327 - acc: 0.8228 - val_loss: 0.6584 - val_acc: 0.7540
# Epoch 289/500
#  - 0s - loss: 0.4398 - acc: 0.8210 - val_loss: 0.6581 - val_acc: 0.7460
# Epoch 290/500
#  - 0s - loss: 0.4226 - acc: 0.8175 - val_loss: 0.6573 - val_acc: 0.7540
# Epoch 291/500
#  - 0s - loss: 0.4325 - acc: 0.8131 - val_loss: 0.6572 - val_acc: 0.7460
# Epoch 292/500
#  - 0s - loss: 0.4252 - acc: 0.8078 - val_loss: 0.6570 - val_acc: 0.7460
# Epoch 293/500
#  - 0s - loss: 0.4302 - acc: 0.8139 - val_loss: 0.6565 - val_acc: 0.7460
# Epoch 294/500
#  - 0s - loss: 0.4287 - acc: 0.8166 - val_loss: 0.6559 - val_acc: 0.7460
# Epoch 295/500
#  - 0s - loss: 0.4276 - acc: 0.8078 - val_loss: 0.6559 - val_acc: 0.7381
# Epoch 296/500
#  - 0s - loss: 0.4323 - acc: 0.8042 - val_loss: 0.6557 - val_acc: 0.7381
# Epoch 297/500
#  - 0s - loss: 0.4354 - acc: 0.8113 - val_loss: 0.6544 - val_acc: 0.7302
# Epoch 298/500
#  - 0s - loss: 0.4232 - acc: 0.8175 - val_loss: 0.6546 - val_acc: 0.7222
# Epoch 299/500
#  - 0s - loss: 0.4362 - acc: 0.8157 - val_loss: 0.6554 - val_acc: 0.7222
# Epoch 300/500
#  - 0s - loss: 0.4332 - acc: 0.8219 - val_loss: 0.6559 - val_acc: 0.7143
# Epoch 301/500
#  - 0s - loss: 0.4264 - acc: 0.8139 - val_loss: 0.6574 - val_acc: 0.7143
# Epoch 302/500
#  - 0s - loss: 0.4371 - acc: 0.8157 - val_loss: 0.6598 - val_acc: 0.7143
# Epoch 303/500
#  - 0s - loss: 0.4301 - acc: 0.8175 - val_loss: 0.6616 - val_acc: 0.7143
# Epoch 304/500
#  - 0s - loss: 0.4244 - acc: 0.8201 - val_loss: 0.6620 - val_acc: 0.7143
# Epoch 305/500
#  - 0s - loss: 0.4264 - acc: 0.8175 - val_loss: 0.6612 - val_acc: 0.7381
# Epoch 306/500
#  - 0s - loss: 0.4193 - acc: 0.8228 - val_loss: 0.6598 - val_acc: 0.7381
# Epoch 307/500
#  - 0s - loss: 0.4372 - acc: 0.8183 - val_loss: 0.6572 - val_acc: 0.7460
# Epoch 308/500
#  - 0s - loss: 0.4255 - acc: 0.8122 - val_loss: 0.6553 - val_acc: 0.7619
# Epoch 309/500
#  - 0s - loss: 0.4197 - acc: 0.8166 - val_loss: 0.6538 - val_acc: 0.7698
# Epoch 310/500
#  - 0s - loss: 0.4303 - acc: 0.8157 - val_loss: 0.6536 - val_acc: 0.7540
# Epoch 311/500
#  - 0s - loss: 0.4291 - acc: 0.8122 - val_loss: 0.6542 - val_acc: 0.7540
# Epoch 312/500
#  - 0s - loss: 0.4261 - acc: 0.8201 - val_loss: 0.6541 - val_acc: 0.7540
# Epoch 313/500
#  - 0s - loss: 0.4218 - acc: 0.8166 - val_loss: 0.6532 - val_acc: 0.7540
# Epoch 314/500
#  - 0s - loss: 0.4182 - acc: 0.8192 - val_loss: 0.6522 - val_acc: 0.7460
# Epoch 315/500
#  - 0s - loss: 0.4237 - acc: 0.8263 - val_loss: 0.6521 - val_acc: 0.7460
# Epoch 316/500
#  - 0s - loss: 0.4288 - acc: 0.8280 - val_loss: 0.6512 - val_acc: 0.7619
# Epoch 317/500
#  - 0s - loss: 0.4290 - acc: 0.8245 - val_loss: 0.6512 - val_acc: 0.7619
# Epoch 318/500
#  - 0s - loss: 0.4213 - acc: 0.8280 - val_loss: 0.6506 - val_acc: 0.7619
# Epoch 319/500
#  - 0s - loss: 0.4272 - acc: 0.8131 - val_loss: 0.6499 - val_acc: 0.7619
# Epoch 320/500
#  - 0s - loss: 0.4250 - acc: 0.8078 - val_loss: 0.6488 - val_acc: 0.7540
# Epoch 321/500
#  - 0s - loss: 0.4267 - acc: 0.8175 - val_loss: 0.6477 - val_acc: 0.7540
# Epoch 322/500
#  - 0s - loss: 0.4090 - acc: 0.8245 - val_loss: 0.6470 - val_acc: 0.7698
# Epoch 323/500
#  - 0s - loss: 0.4230 - acc: 0.8166 - val_loss: 0.6472 - val_acc: 0.7698
# Epoch 324/500
#  - 0s - loss: 0.4200 - acc: 0.8183 - val_loss: 0.6486 - val_acc: 0.7698
# Epoch 325/500
#  - 0s - loss: 0.4221 - acc: 0.8192 - val_loss: 0.6499 - val_acc: 0.7619
# Epoch 326/500
#  - 0s - loss: 0.4131 - acc: 0.8272 - val_loss: 0.6512 - val_acc: 0.7619
# Epoch 327/500
#  - 0s - loss: 0.4116 - acc: 0.8157 - val_loss: 0.6519 - val_acc: 0.7619
# Epoch 328/500
#  - 0s - loss: 0.4085 - acc: 0.8272 - val_loss: 0.6516 - val_acc: 0.7619
# Epoch 329/500
#  - 0s - loss: 0.4106 - acc: 0.8325 - val_loss: 0.6528 - val_acc: 0.7460
# Epoch 330/500
#  - 0s - loss: 0.4150 - acc: 0.8148 - val_loss: 0.6533 - val_acc: 0.7460
# Epoch 331/500
#  - 0s - loss: 0.4255 - acc: 0.8263 - val_loss: 0.6536 - val_acc: 0.7460
# Epoch 332/500
#  - 0s - loss: 0.4276 - acc: 0.8122 - val_loss: 0.6532 - val_acc: 0.7460
# Epoch 333/500
#  - 0s - loss: 0.4245 - acc: 0.8148 - val_loss: 0.6520 - val_acc: 0.7460
# Epoch 334/500
#  - 0s - loss: 0.4055 - acc: 0.8272 - val_loss: 0.6510 - val_acc: 0.7460
# Epoch 335/500
#  - 0s - loss: 0.4207 - acc: 0.8228 - val_loss: 0.6517 - val_acc: 0.7381
# Epoch 336/500
#  - 0s - loss: 0.4288 - acc: 0.8228 - val_loss: 0.6526 - val_acc: 0.7381
# Epoch 337/500
#  - 0s - loss: 0.4122 - acc: 0.8280 - val_loss: 0.6539 - val_acc: 0.7381
# Epoch 338/500
#  - 0s - loss: 0.4105 - acc: 0.8263 - val_loss: 0.6542 - val_acc: 0.7302
# Epoch 339/500
#  - 0s - loss: 0.3994 - acc: 0.8333 - val_loss: 0.6542 - val_acc: 0.7302
# Epoch 340/500
#  - 0s - loss: 0.4142 - acc: 0.8175 - val_loss: 0.6534 - val_acc: 0.7302
# Epoch 341/500
#  - 0s - loss: 0.4147 - acc: 0.8148 - val_loss: 0.6527 - val_acc: 0.7222
# Epoch 342/500
#  - 0s - loss: 0.4154 - acc: 0.8228 - val_loss: 0.6521 - val_acc: 0.7222
# Epoch 343/500
#  - 0s - loss: 0.4125 - acc: 0.8148 - val_loss: 0.6517 - val_acc: 0.7302
# Epoch 344/500
#  - 0s - loss: 0.4254 - acc: 0.8210 - val_loss: 0.6506 - val_acc: 0.7302
# Epoch 345/500
#  - 0s - loss: 0.4051 - acc: 0.8219 - val_loss: 0.6490 - val_acc: 0.7302
# Epoch 346/500
#  - 0s - loss: 0.4171 - acc: 0.8219 - val_loss: 0.6488 - val_acc: 0.7222
# Epoch 347/500
#  - 0s - loss: 0.4134 - acc: 0.8192 - val_loss: 0.6490 - val_acc: 0.7222
# Epoch 348/500
#  - 0s - loss: 0.4149 - acc: 0.8157 - val_loss: 0.6504 - val_acc: 0.7222
# Epoch 349/500
#  - 0s - loss: 0.4053 - acc: 0.8236 - val_loss: 0.6504 - val_acc: 0.7143
# Epoch 350/500
#  - 0s - loss: 0.4075 - acc: 0.8404 - val_loss: 0.6510 - val_acc: 0.7063
# Epoch 351/500
#  - 0s - loss: 0.4232 - acc: 0.8245 - val_loss: 0.6488 - val_acc: 0.7063
# Epoch 352/500
#  - 0s - loss: 0.4086 - acc: 0.8245 - val_loss: 0.6469 - val_acc: 0.7222
# Epoch 353/500
#  - 0s - loss: 0.4119 - acc: 0.8289 - val_loss: 0.6469 - val_acc: 0.7222
# Epoch 354/500
#  - 0s - loss: 0.4188 - acc: 0.8219 - val_loss: 0.6462 - val_acc: 0.7381
# Epoch 355/500
#  - 0s - loss: 0.4086 - acc: 0.8245 - val_loss: 0.6456 - val_acc: 0.7460
# Epoch 356/500
#  - 0s - loss: 0.4092 - acc: 0.8175 - val_loss: 0.6452 - val_acc: 0.7460
# Epoch 357/500
#  - 0s - loss: 0.4141 - acc: 0.8183 - val_loss: 0.6451 - val_acc: 0.7460
# Epoch 358/500
#  - 0s - loss: 0.4093 - acc: 0.8219 - val_loss: 0.6454 - val_acc: 0.7619
# Epoch 359/500
#  - 0s - loss: 0.3974 - acc: 0.8280 - val_loss: 0.6449 - val_acc: 0.7619
# Epoch 360/500
#  - 0s - loss: 0.4170 - acc: 0.8289 - val_loss: 0.6439 - val_acc: 0.7460
# Epoch 361/500
#  - 0s - loss: 0.4132 - acc: 0.8254 - val_loss: 0.6436 - val_acc: 0.7460
# Epoch 362/500
#  - 0s - loss: 0.4142 - acc: 0.8192 - val_loss: 0.6436 - val_acc: 0.7540
# Epoch 363/500
#  - 0s - loss: 0.3932 - acc: 0.8307 - val_loss: 0.6443 - val_acc: 0.7619
# Epoch 364/500
#  - 0s - loss: 0.4110 - acc: 0.8201 - val_loss: 0.6445 - val_acc: 0.7619
# Epoch 365/500
#  - 0s - loss: 0.4095 - acc: 0.8333 - val_loss: 0.6458 - val_acc: 0.7619
# Epoch 366/500
#  - 0s - loss: 0.4066 - acc: 0.8219 - val_loss: 0.6470 - val_acc: 0.7540
# Epoch 367/500
#  - 0s - loss: 0.4227 - acc: 0.8148 - val_loss: 0.6472 - val_acc: 0.7540
# Epoch 368/500
#  - 0s - loss: 0.4169 - acc: 0.8254 - val_loss: 0.6472 - val_acc: 0.7460
# Epoch 369/500
#  - 0s - loss: 0.4046 - acc: 0.8333 - val_loss: 0.6471 - val_acc: 0.7460
# Epoch 370/500
#  - 0s - loss: 0.4079 - acc: 0.8201 - val_loss: 0.6468 - val_acc: 0.7460
# Epoch 371/500
#  - 0s - loss: 0.4155 - acc: 0.8254 - val_loss: 0.6459 - val_acc: 0.7540
# Epoch 372/500
#  - 0s - loss: 0.4103 - acc: 0.8201 - val_loss: 0.6445 - val_acc: 0.7619
# Epoch 373/500
#  - 0s - loss: 0.3957 - acc: 0.8245 - val_loss: 0.6417 - val_acc: 0.7698
# Epoch 374/500
#  - 0s - loss: 0.4208 - acc: 0.8139 - val_loss: 0.6376 - val_acc: 0.7540
# Epoch 375/500
#  - 0s - loss: 0.4152 - acc: 0.8139 - val_loss: 0.6335 - val_acc: 0.7540
# Epoch 376/500
#  - 0s - loss: 0.4016 - acc: 0.8192 - val_loss: 0.6298 - val_acc: 0.7619
# Epoch 377/500
#  - 0s - loss: 0.3957 - acc: 0.8228 - val_loss: 0.6267 - val_acc: 0.7619
# Epoch 378/500
#  - 0s - loss: 0.4136 - acc: 0.8157 - val_loss: 0.6236 - val_acc: 0.7540
# Epoch 379/500
#  - 0s - loss: 0.4102 - acc: 0.8289 - val_loss: 0.6231 - val_acc: 0.7540
# Epoch 380/500
#  - 0s - loss: 0.4111 - acc: 0.8254 - val_loss: 0.6260 - val_acc: 0.7540
# Epoch 381/500
#  - 0s - loss: 0.4066 - acc: 0.8369 - val_loss: 0.6293 - val_acc: 0.7460
# Epoch 382/500
#  - 0s - loss: 0.3956 - acc: 0.8404 - val_loss: 0.6326 - val_acc: 0.7302
# Epoch 383/500
#  - 0s - loss: 0.4066 - acc: 0.8228 - val_loss: 0.6357 - val_acc: 0.7222
# Epoch 384/500
#  - 0s - loss: 0.3985 - acc: 0.8245 - val_loss: 0.6376 - val_acc: 0.7302
# Epoch 385/500
#  - 0s - loss: 0.3865 - acc: 0.8351 - val_loss: 0.6363 - val_acc: 0.7460
# Epoch 386/500
#  - 0s - loss: 0.4103 - acc: 0.8325 - val_loss: 0.6323 - val_acc: 0.7540
# Epoch 387/500
#  - 0s - loss: 0.3996 - acc: 0.8404 - val_loss: 0.6287 - val_acc: 0.7540
# Epoch 388/500
#  - 0s - loss: 0.4075 - acc: 0.8219 - val_loss: 0.6248 - val_acc: 0.7381
# Epoch 389/500
#  - 0s - loss: 0.4114 - acc: 0.8272 - val_loss: 0.6234 - val_acc: 0.7381
# Epoch 390/500
#  - 0s - loss: 0.3997 - acc: 0.8369 - val_loss: 0.6236 - val_acc: 0.7460
# Epoch 391/500
#  - 0s - loss: 0.4083 - acc: 0.8263 - val_loss: 0.6247 - val_acc: 0.7460
# Epoch 392/500
#  - 0s - loss: 0.4061 - acc: 0.8192 - val_loss: 0.6272 - val_acc: 0.7460
# Epoch 393/500
#  - 0s - loss: 0.3988 - acc: 0.8219 - val_loss: 0.6303 - val_acc: 0.7381
# Epoch 394/500
#  - 0s - loss: 0.3978 - acc: 0.8351 - val_loss: 0.6332 - val_acc: 0.7381
# Epoch 395/500
#  - 0s - loss: 0.3970 - acc: 0.8228 - val_loss: 0.6334 - val_acc: 0.7381
# Epoch 396/500
#  - 0s - loss: 0.4064 - acc: 0.8245 - val_loss: 0.6313 - val_acc: 0.7381
# Epoch 397/500
#  - 0s - loss: 0.3991 - acc: 0.8439 - val_loss: 0.6295 - val_acc: 0.7460
# Epoch 398/500
#  - 0s - loss: 0.4075 - acc: 0.8236 - val_loss: 0.6278 - val_acc: 0.7460
# Epoch 399/500
#  - 0s - loss: 0.4074 - acc: 0.8307 - val_loss: 0.6278 - val_acc: 0.7460
# Epoch 400/500
#  - 0s - loss: 0.4003 - acc: 0.8369 - val_loss: 0.6295 - val_acc: 0.7460
# Epoch 401/500
#  - 0s - loss: 0.3977 - acc: 0.8448 - val_loss: 0.6306 - val_acc: 0.7460
# Epoch 402/500
#  - 0s - loss: 0.4076 - acc: 0.8122 - val_loss: 0.6297 - val_acc: 0.7460
# Epoch 403/500
#  - 0s - loss: 0.3996 - acc: 0.8245 - val_loss: 0.6292 - val_acc: 0.7460
# Epoch 404/500
#  - 0s - loss: 0.3924 - acc: 0.8386 - val_loss: 0.6272 - val_acc: 0.7381
# Epoch 405/500
#  - 0s - loss: 0.3965 - acc: 0.8333 - val_loss: 0.6275 - val_acc: 0.7302
# Epoch 406/500
#  - 0s - loss: 0.3841 - acc: 0.8395 - val_loss: 0.6296 - val_acc: 0.7222
# Epoch 407/500
#  - 0s - loss: 0.4034 - acc: 0.8298 - val_loss: 0.6320 - val_acc: 0.7302
# Epoch 408/500
#  - 0s - loss: 0.3939 - acc: 0.8342 - val_loss: 0.6364 - val_acc: 0.7302
# Epoch 409/500
#  - 0s - loss: 0.4016 - acc: 0.8166 - val_loss: 0.6385 - val_acc: 0.7302
# Epoch 410/500
#  - 0s - loss: 0.3977 - acc: 0.8307 - val_loss: 0.6391 - val_acc: 0.7381
# Epoch 411/500
#  - 0s - loss: 0.4113 - acc: 0.8139 - val_loss: 0.6403 - val_acc: 0.7302
# Epoch 412/500
#  - 0s - loss: 0.3858 - acc: 0.8377 - val_loss: 0.6406 - val_acc: 0.7302
# Epoch 413/500
#  - 0s - loss: 0.3915 - acc: 0.8316 - val_loss: 0.6384 - val_acc: 0.7302
# Epoch 414/500
#  - 0s - loss: 0.4039 - acc: 0.8298 - val_loss: 0.6367 - val_acc: 0.7302
# Epoch 415/500
#  - 0s - loss: 0.3906 - acc: 0.8307 - val_loss: 0.6369 - val_acc: 0.7302
# Epoch 416/500
#  - 0s - loss: 0.4009 - acc: 0.8325 - val_loss: 0.6348 - val_acc: 0.7302
# Epoch 417/500
#  - 0s - loss: 0.3835 - acc: 0.8474 - val_loss: 0.6338 - val_acc: 0.7381
# Epoch 418/500
#  - 0s - loss: 0.3928 - acc: 0.8280 - val_loss: 0.6330 - val_acc: 0.7381
# Epoch 419/500
#  - 0s - loss: 0.3892 - acc: 0.8342 - val_loss: 0.6315 - val_acc: 0.7222
# Epoch 420/500
#  - 0s - loss: 0.3911 - acc: 0.8395 - val_loss: 0.6306 - val_acc: 0.7222
# Epoch 421/500
#  - 0s - loss: 0.3876 - acc: 0.8298 - val_loss: 0.6301 - val_acc: 0.7222
# Epoch 422/500
#  - 0s - loss: 0.3935 - acc: 0.8272 - val_loss: 0.6303 - val_acc: 0.7222
# Epoch 423/500
#  - 0s - loss: 0.3906 - acc: 0.8289 - val_loss: 0.6303 - val_acc: 0.7143
# Epoch 424/500
#  - 0s - loss: 0.3880 - acc: 0.8386 - val_loss: 0.6273 - val_acc: 0.7302
# Epoch 425/500
#  - 0s - loss: 0.4008 - acc: 0.8228 - val_loss: 0.6229 - val_acc: 0.7381
# Epoch 426/500
#  - 0s - loss: 0.3957 - acc: 0.8263 - val_loss: 0.6190 - val_acc: 0.7302
# Epoch 427/500
#  - 0s - loss: 0.3927 - acc: 0.8298 - val_loss: 0.6178 - val_acc: 0.7302
# Epoch 428/500
#  - 0s - loss: 0.4044 - acc: 0.8219 - val_loss: 0.6175 - val_acc: 0.7222
# Epoch 429/500
#  - 0s - loss: 0.3877 - acc: 0.8333 - val_loss: 0.6177 - val_acc: 0.7222
# Epoch 430/500
#  - 0s - loss: 0.3906 - acc: 0.8351 - val_loss: 0.6180 - val_acc: 0.7222
# Epoch 431/500
#  - 0s - loss: 0.3864 - acc: 0.8342 - val_loss: 0.6175 - val_acc: 0.7381
# Epoch 432/500
#  - 0s - loss: 0.3922 - acc: 0.8404 - val_loss: 0.6159 - val_acc: 0.7381
# Epoch 433/500
#  - 0s - loss: 0.3988 - acc: 0.8316 - val_loss: 0.6128 - val_acc: 0.7222
# Epoch 434/500
#  - 0s - loss: 0.4001 - acc: 0.8325 - val_loss: 0.6098 - val_acc: 0.7143
# Epoch 435/500
#  - 0s - loss: 0.3872 - acc: 0.8333 - val_loss: 0.6060 - val_acc: 0.7222
# Epoch 436/500
#  - 0s - loss: 0.3976 - acc: 0.8280 - val_loss: 0.6035 - val_acc: 0.7222
# Epoch 437/500
#  - 0s - loss: 0.3944 - acc: 0.8254 - val_loss: 0.6016 - val_acc: 0.7381
# Epoch 438/500
#  - 0s - loss: 0.3863 - acc: 0.8316 - val_loss: 0.6013 - val_acc: 0.7381
# Epoch 439/500
#  - 0s - loss: 0.3879 - acc: 0.8360 - val_loss: 0.6024 - val_acc: 0.7460
# Epoch 440/500
#  - 0s - loss: 0.3988 - acc: 0.8245 - val_loss: 0.6038 - val_acc: 0.7460
# Epoch 441/500
#  - 0s - loss: 0.3864 - acc: 0.8413 - val_loss: 0.6059 - val_acc: 0.7381
# Epoch 442/500
#  - 0s - loss: 0.3945 - acc: 0.8280 - val_loss: 0.6086 - val_acc: 0.7381
# Epoch 443/500
#  - 0s - loss: 0.3906 - acc: 0.8236 - val_loss: 0.6104 - val_acc: 0.7381
# Epoch 444/500
#  - 0s - loss: 0.3865 - acc: 0.8280 - val_loss: 0.6132 - val_acc: 0.7381
# Epoch 445/500
#  - 0s - loss: 0.4076 - acc: 0.8183 - val_loss: 0.6137 - val_acc: 0.7381
# Epoch 446/500
#  - 0s - loss: 0.3943 - acc: 0.8192 - val_loss: 0.6112 - val_acc: 0.7381
# Epoch 447/500
#  - 0s - loss: 0.3970 - acc: 0.8298 - val_loss: 0.6111 - val_acc: 0.7302
# Epoch 448/500
#  - 0s - loss: 0.3924 - acc: 0.8325 - val_loss: 0.6114 - val_acc: 0.7302
# Epoch 449/500
#  - 0s - loss: 0.3896 - acc: 0.8351 - val_loss: 0.6133 - val_acc: 0.7302
# Epoch 450/500
#  - 0s - loss: 0.3879 - acc: 0.8404 - val_loss: 0.6133 - val_acc: 0.7381
# Epoch 451/500
#  - 0s - loss: 0.3897 - acc: 0.8351 - val_loss: 0.6133 - val_acc: 0.7381
# Epoch 452/500
#  - 0s - loss: 0.3846 - acc: 0.8413 - val_loss: 0.6128 - val_acc: 0.7381
# Epoch 453/500
#  - 0s - loss: 0.3914 - acc: 0.8263 - val_loss: 0.6097 - val_acc: 0.7381
# Epoch 454/500
#  - 0s - loss: 0.3838 - acc: 0.8466 - val_loss: 0.6062 - val_acc: 0.7381
# Epoch 455/500
#  - 0s - loss: 0.3817 - acc: 0.8360 - val_loss: 0.5999 - val_acc: 0.7302
# Epoch 456/500
#  - 0s - loss: 0.3990 - acc: 0.8245 - val_loss: 0.5947 - val_acc: 0.7302
# Epoch 457/500
#  - 0s - loss: 0.3994 - acc: 0.8272 - val_loss: 0.5929 - val_acc: 0.7302
# Epoch 458/500
#  - 0s - loss: 0.3917 - acc: 0.8289 - val_loss: 0.5936 - val_acc: 0.7460
# Epoch 459/500
#  - 0s - loss: 0.3852 - acc: 0.8325 - val_loss: 0.5958 - val_acc: 0.7381
# Epoch 460/500
#  - 0s - loss: 0.3974 - acc: 0.8351 - val_loss: 0.5995 - val_acc: 0.7381
# Epoch 461/500
#  - 0s - loss: 0.4136 - acc: 0.8228 - val_loss: 0.6020 - val_acc: 0.7381
# Epoch 462/500
#  - 0s - loss: 0.3919 - acc: 0.8386 - val_loss: 0.6028 - val_acc: 0.7302
# Epoch 463/500
#  - 0s - loss: 0.3882 - acc: 0.8228 - val_loss: 0.6004 - val_acc: 0.7222
# Epoch 464/500
#  - 0s - loss: 0.3803 - acc: 0.8404 - val_loss: 0.5985 - val_acc: 0.7302
# Epoch 465/500
#  - 0s - loss: 0.3844 - acc: 0.8386 - val_loss: 0.5961 - val_acc: 0.7381
# Epoch 466/500
#  - 0s - loss: 0.3918 - acc: 0.8377 - val_loss: 0.5947 - val_acc: 0.7460
# Epoch 467/500
#  - 0s - loss: 0.4008 - acc: 0.8192 - val_loss: 0.5928 - val_acc: 0.7460
# Epoch 468/500
#  - 0s - loss: 0.3887 - acc: 0.8386 - val_loss: 0.5926 - val_acc: 0.7460
# Epoch 469/500
#  - 0s - loss: 0.3938 - acc: 0.8298 - val_loss: 0.5924 - val_acc: 0.7460
# Epoch 470/500
#  - 0s - loss: 0.3997 - acc: 0.8254 - val_loss: 0.5918 - val_acc: 0.7460
# Epoch 471/500
#  - 0s - loss: 0.3922 - acc: 0.8439 - val_loss: 0.5904 - val_acc: 0.7540
# Epoch 472/500
#  - 0s - loss: 0.3891 - acc: 0.8342 - val_loss: 0.5895 - val_acc: 0.7381
# Epoch 473/500
#  - 0s - loss: 0.3843 - acc: 0.8377 - val_loss: 0.5879 - val_acc: 0.7302
# Epoch 474/500
#  - 0s - loss: 0.3913 - acc: 0.8342 - val_loss: 0.5875 - val_acc: 0.7302
# Epoch 475/500
#  - 0s - loss: 0.3904 - acc: 0.8369 - val_loss: 0.5861 - val_acc: 0.7143
# Epoch 476/500
#  - 0s - loss: 0.3949 - acc: 0.8219 - val_loss: 0.5859 - val_acc: 0.7302
# Epoch 477/500
#  - 0s - loss: 0.3946 - acc: 0.8236 - val_loss: 0.5850 - val_acc: 0.7222
# Epoch 478/500
#  - 0s - loss: 0.3957 - acc: 0.8254 - val_loss: 0.5848 - val_acc: 0.7222
# Epoch 479/500
#  - 0s - loss: 0.3841 - acc: 0.8360 - val_loss: 0.5862 - val_acc: 0.7222
# Epoch 480/500
#  - 0s - loss: 0.3896 - acc: 0.8333 - val_loss: 0.5867 - val_acc: 0.7222
# Epoch 481/500
#  - 0s - loss: 0.3974 - acc: 0.8289 - val_loss: 0.5850 - val_acc: 0.7381
# Epoch 482/500
#  - 0s - loss: 0.3849 - acc: 0.8457 - val_loss: 0.5845 - val_acc: 0.7302
# Epoch 483/500
#  - 0s - loss: 0.3917 - acc: 0.8280 - val_loss: 0.5827 - val_acc: 0.7302
# Epoch 484/500
#  - 0s - loss: 0.3869 - acc: 0.8360 - val_loss: 0.5830 - val_acc: 0.7302
# Epoch 485/500
#  - 0s - loss: 0.3877 - acc: 0.8316 - val_loss: 0.5858 - val_acc: 0.7302
# Epoch 486/500
#  - 0s - loss: 0.3972 - acc: 0.8236 - val_loss: 0.5888 - val_acc: 0.7381
# Epoch 487/500
#  - 0s - loss: 0.3781 - acc: 0.8369 - val_loss: 0.5930 - val_acc: 0.7460
# Epoch 488/500
#  - 0s - loss: 0.3830 - acc: 0.8519 - val_loss: 0.5971 - val_acc: 0.7222
# Epoch 489/500
#  - 0s - loss: 0.4001 - acc: 0.8280 - val_loss: 0.5988 - val_acc: 0.7302
# Epoch 490/500
#  - 0s - loss: 0.3984 - acc: 0.8272 - val_loss: 0.5979 - val_acc: 0.7222
# Epoch 491/500
#  - 0s - loss: 0.3783 - acc: 0.8413 - val_loss: 0.5964 - val_acc: 0.7222
# Epoch 492/500
#  - 0s - loss: 0.3824 - acc: 0.8448 - val_loss: 0.5930 - val_acc: 0.7222
# Epoch 493/500
#  - 0s - loss: 0.3885 - acc: 0.8395 - val_loss: 0.5903 - val_acc: 0.7063
# Epoch 494/500
#  - 0s - loss: 0.3871 - acc: 0.8298 - val_loss: 0.5890 - val_acc: 0.7063
# Epoch 495/500
#  - 0s - loss: 0.3799 - acc: 0.8413 - val_loss: 0.5884 - val_acc: 0.6984
# Epoch 496/500
#  - 0s - loss: 0.3900 - acc: 0.8342 - val_loss: 0.5890 - val_acc: 0.6984
# Epoch 497/500
#  - 0s - loss: 0.3804 - acc: 0.8369 - val_loss: 0.5889 - val_acc: 0.6825
# Epoch 498/500
#  - 0s - loss: 0.3873 - acc: 0.8351 - val_loss: 0.5895 - val_acc: 0.6905
# Epoch 499/500
#  - 0s - loss: 0.3903 - acc: 0.8439 - val_loss: 0.5907 - val_acc: 0.6825
# Epoch 500/500
#  - 0s - loss: 0.3902 - acc: 0.8377 - val_loss: 0.5951 - val_acc: 0.6667

# %%
test_set = test_set_with_spreads(seeds,season_results, meta, spreads_df)

# %%
score_normed_deep_model(training_set, model)
# Out:
# 1260/1260 [==============================] - 0s 61us/step
# [0.51849292800540014, 0.79126984108062015]

# %%
predictions = predict_with_normed_deep_model(test_set, model)

# %%
write_predictions(test_set['Key'].values.reshape((len(test_set), 1)), predictions)
